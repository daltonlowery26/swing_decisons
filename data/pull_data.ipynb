# %% [markdown]
# ### pull pybaseball data

# %%
import pandas as pd 
from pybaseball import statcast
from pybaseball import statcast_batter

# %%
df = statcast('2024-09-01', '2024-12-30')
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
#   0%|          | 0/76 [00:00<?, ?it/s]c:\Users\dalto\anaconda3\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
#   1%|▏         | 1/76 [00:08<10:51,  8.69s/it]c:\Users\dalto\anaconda3\Lib\site-packages\pybaseball\datahelpers\postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# ...
